# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import math

# %%
df = pd.read_csv('Addiction.csv',encoding= 'unicode_escape')
df1 = pd.read_csv('Anxiety.csv',encoding= 'unicode_escape')
df2 = pd.read_csv('Alcoholism.csv',encoding= 'unicode_escape')
df3 = pd.read_csv('Depression.csv',encoding= 'unicode_escape')
df4 = pd.read_csv('Schizophrenia.csv',encoding= 'unicode_escape')
df5 = pd.read_csv('Neutral.csv',encoding= 'unicode_escape')

# %%
data = df.append(df1, ignore_index=True)
data1= data.append(df2, ignore_index=True)
data2= data1.append(df3, ignore_index=True)
data3= data2.append(df4, ignore_index=True)
data4= data3.append(df5, ignore_index=True)

# %%
data4.head
# Out:
# <bound method NDFrame.head of                                             Description Mental State
# 0     I'm sorry about this post. It's gonna be a who...    Addiction
# 1     Been getting super high off high amounts of th...    Addiction
# 2     My brothers been shooting heroin/meth for the ...    Addiction
# 3     I rlly need an opinion cuz idk bout this stuff...    Addiction
# 4     Ive smoked weed since 8th grade in middle scho...    Addiction
# ...                                                 ...          ...
# 6401  possible have satpathy ask question the questi...      neutral
# 6402                              god that was thorough      neutral
# 6403                      thread and meat kaun jat bhai      neutral
# 6404     not touch food with your left hand left handed      neutral
# 6405                     they say because they care for      neutral
#
# [6406 rows x 2 columns]>

# %%
data4.to_csv("mental_health.csv")

# %%
data4.groupby("Mental State").describe()
# Out:
#               Description         \
#                     count unique
# Mental State
# Addiction             998    992
# Alcoholism            999    995
# Anxiety              1024   1024
# Depression           1024   1024
# Schizophernia        1024   1023
# neutral              1024   1024
#
#
#                                                              top freq
# Mental State
# Addiction      I?m 16 years old and I want to start smoking, ...    2
# Alcoholism     I didn?t learn my lesson from my first bout wi...    2
# Anxiety        This may sound off topic but I'm really scared...    1
# Depression     I need help I don't cry but I'm crying my whol...    1
# Schizophernia  What happened to you or a loved one to become ...    2
# neutral        What did you get?  My day is alright.. haven`t...    1

# %%
df5.head
# Out:
# <bound method NDFrame.head of                                             Description Mental State
# 0     What did you get?  My day is alright.. haven`t...      neutral
# 1                             I checked.  We didn`t win      neutral
# 2     you`re on twitter! Did the tavern bore you tha...      neutral
# 3     I`m going into a spiritual stagnentation, its ...      neutral
# 4     hey peoples, dont you just hate being grounded...      neutral
# ...                                                 ...          ...
# 1019  possible have satpathy ask question the questi...      neutral
# 1020                              god that was thorough      neutral
# 1021                      thread and meat kaun jat bhai      neutral
# 1022     not touch food with your left hand left handed      neutral
# 1023                     they say because they care for      neutral
#
# [1024 rows x 2 columns]>

# %%
df = pd.read_csv('mental_health.csv',encoding= 'unicode_escape')

# %%
df.head
# Out:
# <bound method NDFrame.head of       Unnamed: 0                                        Description  \
# 0              0  I'm sorry about this post. It's gonna be a who...
# 1              1  Been getting super high off high amounts of th...
# 2              2  My brothers been shooting heroin/meth for the ...
# 3              3  I rlly need an opinion cuz idk bout this stuff...
# 4              4  Ive smoked weed since 8th grade in middle scho...
# ...          ...                                                ...
# 6401        6401  possible have satpathy ask question the questi...
# 6402        6402                              god that was thorough
# 6403        6403                      thread and meat kaun jat bhai
# 6404        6404     not touch food with your left hand left handed
# 6405        6405                     they say because they care for
#
#      Mental State
# 0       Addiction
# 1       Addiction
# 2       Addiction
# 3       Addiction
# 4       Addiction
# ...           ...
# 6401      neutral
# 6402      neutral
# 6403      neutral
# 6404      neutral
# 6405      neutral
#
# [6406 rows x 3 columns]>

# %%
df.groupby("Mental State").describe()
# Out:
#               Unnamed: 0                                               \
#                    count    mean         std     min      25%     50%
# Mental State
# Addiction          998.0   498.5  288.242086     0.0   249.25   498.5
# Alcoholism         999.0  2617.0  288.530761  2118.0  2367.50  2617.0
# Anxiety           1024.0  1509.5  295.747640   998.0  1253.75  1509.5
# Depression        1024.0  3628.5  295.747640  3117.0  3372.75  3628.5
# Schizophernia     1024.0  4759.5  295.747640  4248.0  4503.75  4759.5
# neutral           1024.0  5893.5  295.747640  5382.0  5637.75  5893.5
#
#
#                    75%     max
# Mental State
# Addiction       747.75   997.0
# Alcoholism     2866.50  3116.0
# Anxiety        1765.25  2021.0
# Depression     3884.25  4140.0
# Schizophernia  5015.25  5271.0
# neutral        6149.25  6405.0

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Description', 'Mental State'], dtype='object')

# %%
df.drop(labels='Unnamed: 0', axis=1)
# Out:
#                                             Description Mental State
# 0     I'm sorry about this post. It's gonna be a who...    Addiction
# 1     Been getting super high off high amounts of th...    Addiction
# 2     My brothers been shooting heroin/meth for the ...    Addiction
# 3     I rlly need an opinion cuz idk bout this stuff...    Addiction
# 4     Ive smoked weed since 8th grade in middle scho...    Addiction
# ...                                                 ...          ...
# 6401  possible have satpathy ask question the questi...      neutral
# 6402                              god that was thorough      neutral
# 6403                      thread and meat kaun jat bhai      neutral
# 6404     not touch food with your left hand left handed      neutral
# 6405                     they say because they care for      neutral
#
# [6406 rows x 2 columns]

# %%
df.isnull()
# Out:
#       Unnamed: 0  Description  Mental State
# 0          False        False         False
# 1          False        False         False
# 2          False        False         False
# 3          False        False         False
# 4          False        False         False
# ...          ...          ...           ...
# 6401       False        False         False
# 6402       False        False         False
# 6403       False        False         False
# 6404       False        False         False
# 6405       False        False         False
#
# [6406 rows x 3 columns]

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (6093, 3)

# %%
df.groupby("Mental State").describe()
# Out:
#               Unnamed: 0                                               \
#                    count    mean         std     min      25%     50%
# Mental State
# Addiction          998.0   498.5  288.242086     0.0   249.25   498.5
# Alcoholism         999.0  2617.0  288.530761  2118.0  2367.50  2617.0
# Anxiety           1024.0  1509.5  295.747640   998.0  1253.75  1509.5
# Depression        1024.0  3628.5  295.747640  3117.0  3372.75  3628.5
# Schizophernia     1024.0  4759.5  295.747640  4248.0  4503.75  4759.5
# neutral           1024.0  5893.5  295.747640  5382.0  5637.75  5893.5
#
#
#                    75%     max
# Mental State
# Addiction       747.75   997.0
# Alcoholism     2866.50  3116.0
# Anxiety        1765.25  2021.0
# Depression     3884.25  4140.0
# Schizophernia  5015.25  5271.0
# neutral        6149.25  6405.0

# %%
plt.subplots(figsize=(10,7))
sns.countplot(df["Mental State"])
plt.show()
# Out:
# C:\Users\fahim\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
